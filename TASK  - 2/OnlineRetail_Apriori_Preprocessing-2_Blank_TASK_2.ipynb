# %% [markdown]
# # 🧺 Online Retail Dataset (Apriori Preprocessing) - TASK 2
# **Dataset**: https://www.kaggle.com/datasets/vijayuv/onlineretail
# <center><b><h1>Viraj Odedra | 23010101178 | 334 </b></center>

# %% [markdown]
# # Step 1: Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('OnlineRetail.csv', encoding = 'ISO-8859-1')
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 2: Drop Missing Invoices or Descriptions

# %%
data2 = pd.read_csv('OnlineRetail.csv', encoding = 'ISO-8859-1')

# df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# removes the row where the mising value (null). if how = all it removes the column when all data is null.
data_after_process = data2.dropna(how = 'any' ,subset = ["InvoiceNo", "Description"])
data_after_process
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 3: Remove Canceled Invoices <BR> Start with letter 'c'

# %%
invoice_in_str = data_after_process['InvoiceNo'].astype(str)

temp = []  

for invoice in invoice_in_str :
    if(invoice.startswith('C')) :
        temp.append(True)
    else:
        temp.append(False)

print("Number of canceled invoices:", temp.count(True))

flag_list = []
for flag in temp :
    flag_list.append(not flag)

remaining_data = data_after_process[flag_list]
remaining_data
# Out:
# Number of canceled invoices: 9288
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 4: Keep Only Positive Quantities

# %%
positive_data = remaining_data.query('Quantity > 0')

# data_after_process = positive_data.drop(positive_data.index)
# data_after_prccess

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 5: Standardize Item Descriptions | Lower case and remove space

# %%
positive_data = positive_data.copy()  # used to solve the error
positive_data['Description'] = positive_data['Description'].str.lower()
positive_data['Description'] = positive_data['Description'].str.replace(' ', '')
positive_data


# or 
# positive_data.loc[:, 'Description'] = (
#     positive_data['Description']
#     .str.lower()
#     .str.replace(' ', '')
# )
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 0         536365    85123A  whitehangingheartt-lightholder         6
# 1         536365     71053               whitemetallantern         6
# 2         536365    84406B      creamcupidheartscoathanger         8
# 3         536365    84029G  knittedunionflaghotwaterbottle         6
# 4         536365    84029E      redwoollyhottiewhiteheart.         6
# ...          ...       ...                             ...       ...
# 541904    581587     22613         packof20spaceboynapkins        12
# 541905    581587     22899        children'saprondollygirl         6
# 541906    581587     23254       childrenscutlerydollygirl         4
# 541907    581587     23255    childrenscutlerycircusparade         4
# 541908    581587     22138        bakingset9pieceretrospot         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# ...

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   white hanging heart t-light holder         6
# 1         536365     71053                  white metal lantern         6
# 2         536365    84406B       cream cupid hearts coat hanger         8
# 3         536365    84029G  knitted union flag hot water bottle         6
# 4         536365    84029E       red woolly hottie white heart.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          pack of 20 spaceboy napkins        12
# 541905    581587     22899          children's apron dolly girl         6
# 541906    581587     23254         childrens cutlery dolly girl         4
# 541907    581587     23255      childrens cutlery circus parade         4
# 541908    581587     22138         baking set 9 piece retrospot         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 6: Filter for a Single Country (e.g., United Kingdom)

# %%
data_uk_filtered = positive_data.query("Country == 'United Kingdom'")
data_uk_filtered
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 0         536365    85123A  whitehangingheartt-lightholder         6
# 1         536365     71053               whitemetallantern         6
# 2         536365    84406B      creamcupidheartscoathanger         8
# 3         536365    84029G  knittedunionflaghotwaterbottle         6
# 4         536365    84029E      redwoollyhottiewhiteheart.         6
# ...          ...       ...                             ...       ...
# 541889    581585     22466      fairytalecottagenightlight        12
# 541890    581586     22061  largecakestandhangingstrawbery         8
# 541891    581586     23275      setof3hangingowlsolliebeak        24
# 541892    581586     21217       redretrospotroundcaketins        24
# 541893    581586     20685             doormatredretrospot        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# ...

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   white hanging heart t-light holder         6
# 1         536365     71053                  white metal lantern         6
# 2         536365    84406B       cream cupid hearts coat hanger         8
# 3         536365    84029G  knitted union flag hot water bottle         6
# 4         536365    84029E       red woolly hottie white heart.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       fairy tale cottage night light        12
# 541890    581586     22061  large cake stand  hanging strawbery         8
# 541891    581586     23275     set of 3 hanging owls ollie beak        24
# 541892    581586     21217        red retrospot round cake tins        24
# 541893    581586     20685                doormat red retrospot        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 7: Remove Duplicates

# %%
pure_data = data_uk_filtered.drop_duplicates()
pure_data
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 0         536365    85123A  whitehangingheartt-lightholder         6
# 1         536365     71053               whitemetallantern         6
# 2         536365    84406B      creamcupidheartscoathanger         8
# 3         536365    84029G  knittedunionflaghotwaterbottle         6
# 4         536365    84029E      redwoollyhottiewhiteheart.         6
# ...          ...       ...                             ...       ...
# 541889    581585     22466      fairytalecottagenightlight        12
# 541890    581586     22061  largecakestandhangingstrawbery         8
# 541891    581586     23275      setof3hangingowlsolliebeak        24
# 541892    581586     21217       redretrospotroundcaketins        24
# 541893    581586     20685             doormatredretrospot        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# ...

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   white hanging heart t-light holder         6
# 1         536365     71053                  white metal lantern         6
# 2         536365    84406B       cream cupid hearts coat hanger         8
# 3         536365    84029G  knitted union flag hot water bottle         6
# 4         536365    84029E       red woolly hottie white heart.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       fairy tale cottage night light        12
# 541890    581586     22061  large cake stand  hanging strawbery         8
# 541891    581586     23275     set of 3 hanging owls ollie beak        24
# 541892    581586     21217        red retrospot round cake tins        24
# 541893    581586     20685                doormat red retrospot        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 8: Add TotalPrice column , TotalPrice = Quantity *  UnitPrice

# %%
data_step_8 = pure_data.copy()
data_step_8['TotalPrice'] = data['Quantity'] * data['UnitPrice']
data_step_8
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 0         536365    85123A  whitehangingheartt-lightholder         6
# 1         536365     71053               whitemetallantern         6
# 2         536365    84406B      creamcupidheartscoathanger         8
# 3         536365    84029G  knittedunionflaghotwaterbottle         6
# 4         536365    84029E      redwoollyhottiewhiteheart.         6
# ...          ...       ...                             ...       ...
# 541889    581585     22466      fairytalecottagenightlight        12
# 541890    581586     22061  largecakestandhangingstrawbery         8
# 541891    581586     23275      setof3hangingowlsolliebeak        24
# 541892    581586     21217       redretrospotroundcaketins        24
# 541893    581586     20685             doormatredretrospot        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %%
# Out:
# /var/folders/by/8_8v2yf54c11829sxdn1r3400000gn/T/ipykernel_10486/2868551681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   white hanging heart t-light holder         6
# 1         536365     71053                  white metal lantern         6
# 2         536365    84406B       cream cupid hearts coat hanger         8
# 3         536365    84029G  knitted union flag hot water bottle         6
# 4         536365    84029E       red woolly hottie white heart.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       fairy tale cottage night light        12
# 541890    581586     22061  large cake stand  hanging strawbery         8
# 541891    581586     23275     set of 3 hanging owls ollie beak        24
# 541892    581586     21217        red retrospot round cake tins        24
# 541893    581586     20685                doormat red retrospot        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# # Step 9 : Check for Top 10 Selling Products

# %%
top_data = pure_data.groupby('Description')['Quantity'].sum().sort_values(ascending = False).head(10)
top_data
# Out:
# Description
# papercraft,littlebirdie           80995
# mediumceramictopstoragejar        77036
# worldwar2glidersasstddesigns      49430
# jumbobagredretrospot              44165
# whitehangingheartt-lightholder    35726
# popcornholder                     34726
# assortedcolourbirdornament        33636
# packof12londontissues             25315
# packof72retrospotcakecases        24963
# victorianglasshangingt-light      23663
# Name: Quantity, dtype: int64

# %%
# Out:
# white hanging heart t-light holder    2218
# jumbo bag red retrospot               1957
# regency cakestand 3 tier              1702
# party bunting                         1607
# lunch bag red retrospot               1409
# assorted colour bird ornament         1391
# set of 3 cake tins pantry design      1248
# lunch bag  black skull.               1244
# natural slate heart chalkboard        1225
# heart of wicker small                 1181
# Name: Description, dtype: int64

# %% [markdown]
# # Step 10 : Identify Most Active Customers

# %%
top_products = pure_data.groupby('Description')['Quantity'].count()
top_products = top_products.sort_values(ascending=False)
top_products.head(10)


# top_products2 = pure_data.groupby('InvoiceNo').max()
# top_products
# Out:
# Description
# whitehangingheartt-lightholder    2220
# jumbobagredretrospot              1957
# regencycakestand3tier             1702
# partybunting                      1608
# lunchbagredretrospot              1409
# assortedcolourbirdornament        1392
# setof3caketinspantrydesign        1248
# lunchbagblackskull.               1244
# naturalslateheartchalkboard       1225
# lunchbagsukidesign                1221
# Name: Quantity, dtype: int64

# %%
# Out:
# 17841.0    7675
# 14096.0    5109
# 12748.0    4411
# 14606.0    2677
# 15311.0    2366
# 13089.0    1814
# 13263.0    1667
# 14298.0    1637
# 15039.0    1477
# 18118.0    1263
# Name: CustomerID, dtype: int64

# %% [markdown]
# # Step 11: Time-Based Analysis | Convert InvoiceDate to datetime and check popular months/hours.

# %%
data['InvoiceMonth']=pd.to_datetime(data['InvoiceDate']).dt.month.value_counts().sort_index()
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  InvoiceMonth
# ...

# %% [markdown]
# # Step 12: Convert to Basket Format

# %% [markdown]
# Example
# <table border="1">
#     <thead>
#         <tr>
#             <th>Transaction</th>
#             <th>Milk</th>
#             <th>Bread</th>
#             <th>Butter</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr><td>T1</td><td>1</td><td>1</td><td>1</td></tr>
#         <tr><td>T2</td><td>0</td><td>1</td><td>1</td></tr>
#         <tr><td>T3</td><td>1</td><td>0</td><td>0</td></tr>
#         <tr><td>T4</td><td>1</td><td>1</td><td>0</td></tr>
#         <tr><td>T5</td><td>0</td><td>1</td><td>1</td></tr>
#     </tbody>
# </table>

# %%
# Out:
# Description  *boombox ipod classic  *usb office mirror ball  \
# InvoiceNo
# 536365                           0                        0
# 536366                           0                        0
# 536367                           0                        0
# 536368                           0                        0
# 536369                           0                        0
# ...                            ...                      ...
# 581585                           0                        0
# 581586                           0                        0
# A563185                          0                        0
# A563186                          0                        0
# A563187                          0                        0
#
# Description  10 colour spaceboy pen  12 coloured party balloons  \
# InvoiceNo
# 536365                            0                           0
# 536366                            0                           0
# ...

# %% [markdown]
# # Step:13 : Save Basket Format into CSV file
